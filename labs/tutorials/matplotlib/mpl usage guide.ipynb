# %% [markdown]
# # usage guide

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots() # figure with one axis
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]) # data -> axes

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3]) # mpl plot

# %% [markdown]
# ### figure

# %%
fig = plt.figure() # new figure, no axes
fig, ax = plt.subplots() # figure with one axes
fig, ax = plt.subplots(2, 2) # figure with 2x2 grid of Axes

# %% [markdown]
# ### axes

# %%
# Axes have Axis objects (Axes can only be in one figure)

# %% [markdown]
# ### axis

# %%
# ticks -- Locator
# ticklabel strings -- Formatter

# %% [markdown]
# ### artist

# %%
# texts
# line2d
# collections
# Patch

# artist <--> Axes

# %% [markdown]
# ### types of inputs to plotting funcs

# %%
# do numpy.array not pandas stuff

# pandas
import pandas
a = pandas.DataFrame(np.random.rand(4, 5), columns = list('abcde'))
a_asarray = a.values # to numpy.array

# w/ numpy.matrix
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b) # to numpy.array

# %% [markdown]
# ### OO interface and pyplot interface

# %%
# OBJECT ORIENTED STYLE

x = np.linspace(0, 2, 100)

fig, ax = plt.subplots() # figure + axes
ax.plot(x, x, label='linear') # data --> axes axes
ax.plot(x, x**2, label='quadratic') # data --> axes
ax.plot(x, x**3, label='cubic') # data --> axes
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title("Simple Plot")
ax.legend()

# %%
# PYPLOT STYLE

x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear') # implicit axes here
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
from pylab import * # all pyplot and numpy

x = linspace(0, 2, 100)
plot(x, x, label='linear')

# wild... so don't do this.

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph
    
    Parameters 
    ----------
    ax : Axes
        The axes drawn to
        
    data1 : array
        The x data
        
    data2 : array
        The y data
        
    param_dict : dict
        Dictionary of kwargs to pass to ax.plot
        
    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# usage later
data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker' : 'x'})

# %%
fig, (ax1, ax2) = plt.subplots(1, 2) # 2 subplots this time
my_plotter(ax1, data1, data2, {'marker' : 'x'})
my_plotter(ax2, data3, data4, {'marker' : 'o'})

# %% [markdown]
# ### backends

# %%
# 1. rcParams['backend'] in matplotlibrc file -- priority 3
# 2. MPLBACKEND -- priotity 2
# 3. matplotlib.use() -- priority 1

# DISPLAY unset -- event loop is headless 
# (now noninteractive backend, or agg)

# config method 1 -- setting rcParams['backend'] 
# (default: 'agg') in matplotlibrc file
#
# backend : qt5agg # pyqt5 w/ antigrain (agg) rendering

# config method 2 -- MPLBACKEND var
# current shell or script
#
# export MPLBACKEND=qt5agg
# python simple_plot.py
# /OR/
# MPLBACKEND=qt5agg python simple_plot.py

# config method 3 -- matplotlib.use()
# import matplotlib
# matplotlib.use('qt5agg') -- BEFORE figure creation

# %% [markdown]
# ### builtin backends

# %%
# AGG (Anti-Grain Geometry) and Cairo

# vector: drawing command, scale free
# raster: pixel-based (dependent on DPI)

# AGG - png - raster - high quality images
# PDF - pdf - vector
# PS - ps, eps - vector - Postscript
# SVG - svg - vector - Scalable Vector Graphics
# PGF - pgf, pdf - vector - using pgf
# Cairo - png, ps, pdf, svg - raster OR vector - Cairo lib


# save to non-interactive backends?
# use matplotlib.pyplot.savefig('filename')

# %% [markdown]
# ### interactive mode

# %%
# interact calls
# mpl.interactive()
# mpl.is_interactive()

# alternative calls
# mpl.pyplot.ion()
# mpl.pyplot.ioff()
# Out:
# True

# %%
import matplotlib.pyplot as plt
plt.ion()
plt.plot([1.6, 2.7])

# %%
plt.title("interactive test")
plt.xlabel("index")
# Out:
# Text(0.5, 0, 'index')

# %%
ax = plt.gca()
ax.plot([3.1, 2.2])

# %%
plt.draw()

# %%
import matplotlib.pyplot as plt
plt.ioff()
plt.plot([1.6, 2.7])

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.ioff()
for i in range(3):
    plt.plot(np.random.rand(10))
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# Setup, and create the data to plot
y = np.random.rand(100000)
y[50000:] *= 2
y[np.geomspace(10, 50000, 400).astype(int)] = -1
mpl.rcParams['path.simplify'] = True

mpl.rcParams['path.simplify_threshold'] = 0.0
plt.plot(y)
plt.show()

# %%
mpl.rcParams['path.simplify_threshold'] = 1.0
plt.plot(y)
plt.show()

# %%
plt.plot(y, y, markevery=10)

# %%
mpl.rcParams['path.simplify_threshold'] = 1.0

# setup, and create the data to plot
y = np.random.rand(100000)
y[50000:] *= 2
y[np.geomspace(10, 50000, 400).astype(int)] = -1
mpl.rcParams['path.simplify'] = True

# mpl.rcParams['agg.path_chunksize'] = 0
# plt.plot(y)
# plt.show()

# %%
# mpl.rcParams['agg.path_chunksize'] = 10000
# plt.plot(y)
# plt.show()

# %%
import matplotlib.style as mplstyle
mplstyle.use('fast')
# Out:
# <function matplotlib.style.core.use(style)>

# %%
mplstyle.use(['dark_background', "ggplot", "fast"])
