# %% [markdown]
# # pyplot tutorial

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares, and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
# my own example
plt.xlabel('number of days passed')
plt.ylabel("FUBO's motivation to work")
plt.plot(t, 45*t**(-1/2), 'r^')
plt.show()
# Out:
# <ipython-input-14-f39dac15e1cd>:4: RuntimeWarning: divide by zero encountered in power
#   plt.plot(t, 45*t**(-1/2), 'r^')
